# %% [markdown]
# # Proyek Analisis Data: Air Quality[Input Nama Dataset]
# - **Nama: Nabil Defin Jatmiko** [Input Nama]
# - **Email: nabildefinjatmiko@gmail.com** [Input Email]
# - **ID Dicoding: MC229D5Y0769** [Input Username]

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana hubungan antara cuaca dengan tingkat polusi udara yang berkonsentrasi PM2.5 di setiap station?
# - Bagaimana tren perubahan rata-rata tingkat polusi udara yang berkonsentrasi PM2.5 perbulannya di semua station?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
aotizhongxin_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Aotizhongxin_20130301-20170228.csv")# menginput file aotizhongxin yang berbentuk csv
aotizhongxin_df.head() # menampilkan 5 data teratas dai file aotizhongxin
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0   4.0   7.0  300.0  77.0  -0.7
# 1   2  2013      3    1     1    8.0   8.0   4.0   7.0  300.0  77.0  -1.1
# 2   3  2013      3    1     2    7.0   7.0   5.0  10.0  300.0  73.0  -1.1
# 3   4  2013      3    1     3    6.0   6.0  11.0  11.0  300.0  72.0  -1.4
# 4   5  2013      3    1     4    3.0   3.0  12.0  12.0  300.0  72.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1023.0 -18.8   0.0  NNW   4.4  Aotizhongxin
# 1  1023.2 -18.2   0.0    N   4.7  Aotizhongxin
# 2  1023.5 -18.2   0.0  NNW   5.6  Aotizhongxin
# 3  1024.5 -19.4   0.0   NW   3.1  Aotizhongxin
# 4  1025.2 -19.5   0.0    N   2.0  Aotizhongxin

# %%
changping_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Changping_20130301-20170228.csv")# menginput file changping yang berbentuk csv
changping_df.head() # menampilkan 5 data teratas dai file changping
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  13.0   7.0  300.0  85.0  -2.3
# 1   2  2013      3    1     1    3.0   3.0   6.0   6.0  300.0  85.0  -2.5
# 2   3  2013      3    1     2    3.0   3.0  22.0  13.0  400.0  74.0  -3.0
# 3   4  2013      3    1     3    3.0   6.0  12.0   8.0  300.0  81.0  -3.6
# 4   5  2013      3    1     4    3.0   3.0  14.0   8.0  300.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM    station
# 0  1020.8 -19.7   0.0    E   0.5  Changping
# 1  1021.3 -19.0   0.0  ENE   0.7  Changping
# 2  1021.3 -19.9   0.0  ENE   0.2  Changping
# 3  1021.8 -19.1   0.0  NNE   1.0  Changping
# 4  1022.3 -19.4   0.0    N   2.1  Changping

# %%
dingling_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Dingling_20130301-20170228.csv")# menginput file dingling yang berbentuk csv
dingling_df.head()# menampilkan 5 data teratas dai file dingling
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  3.0  NaN  200.0  82.0  -2.3
# 1   2  2013      3    1     1    7.0   7.0  3.0  NaN  200.0  80.0  -2.5
# 2   3  2013      3    1     2    5.0   5.0  3.0  2.0  200.0  79.0  -3.0
# 3   4  2013      3    1     3    6.0   6.0  3.0  NaN  200.0  79.0  -3.6
# 4   5  2013      3    1     4    5.0   5.0  3.0  NaN  200.0  81.0  -3.5
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1020.8 -19.7   0.0    E   0.5  Dingling
# 1  1021.3 -19.0   0.0  ENE   0.7  Dingling
# 2  1021.3 -19.9   0.0  ENE   0.2  Dingling
# 3  1021.8 -19.1   0.0  NNE   1.0  Dingling
# 4  1022.3 -19.4   0.0    N   2.1  Dingling

# %%
dongsi_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Dongsi_20130301-20170228.csv")# menginput file dongsi yang berbentuk csv
dongsi_df.head()# menampilkan 5 data teratas dai file dongsi
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  3.0  17.0  300.0  89.0  -0.5
# 1   2  2013      3    1     1    4.0   4.0  3.0  16.0  300.0  88.0  -0.7
# 2   3  2013      3    1     2    7.0   7.0  NaN  17.0  300.0  60.0  -1.2
# 3   4  2013      3    1     3    3.0   3.0  5.0  18.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0   3.0  7.0   NaN  200.0  84.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1024.5 -21.4   0.0  NNW   5.7  Dongsi
# 1  1025.1 -22.1   0.0   NW   3.9  Dongsi
# 2  1025.3 -24.6   0.0  NNW   5.3  Dongsi
# 3  1026.2 -25.5   0.0    N   4.9  Dongsi
# 4  1027.1 -24.5   0.0  NNW   3.2  Dongsi

# %%
guanyuan_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Guanyuan_20130301-20170228.csv")# menginput file guanyuan yang berbentuk csv
guanyuan_df.head()# menampilkan 5 data teratas dai file guanyuan
# Out:
#    No  year  month  day  hour  PM2.5  PM10   SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    4.0   4.0  14.0  20.0  300.0  69.0  -0.7
# 1   2  2013      3    1     1    4.0   4.0  13.0  17.0  300.0  72.0  -1.1
# 2   3  2013      3    1     2    3.0   3.0  10.0  19.0  300.0  69.0  -1.1
# 3   4  2013      3    1     3    3.0   6.0   7.0  24.0  400.0  62.0  -1.4
# 4   5  2013      3    1     4    3.0   6.0   5.0  14.0  400.0  71.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM   station
# 0  1023.0 -18.8   0.0  NNW   4.4  Guanyuan
# 1  1023.2 -18.2   0.0    N   4.7  Guanyuan
# 2  1023.5 -18.2   0.0  NNW   5.6  Guanyuan
# 3  1024.5 -19.4   0.0   NW   3.1  Guanyuan
# 4  1025.2 -19.5   0.0    N   2.0  Guanyuan

# %%
gucheng_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Gucheng_20130301-20170228.csv")# menginput file gucheng yang berbentuk csv
gucheng_df.head()# menampilkan 5 data teratas dai file gucheng
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0  18.0  5.0  NaN  800.0  88.0   0.1
# 1   2  2013      3    1     1    6.0  15.0  5.0  NaN  800.0  88.0  -0.3
# 2   3  2013      3    1     2    5.0  18.0  NaN  NaN  700.0  52.0  -0.7
# 3   4  2013      3    1     3    6.0  20.0  6.0  NaN    NaN   NaN  -1.0
# 4   5  2013      3    1     4    5.0  17.0  5.0  NaN  600.0  73.0  -1.3
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1021.1 -18.6   0.0   NW   4.4  Gucheng
# 1  1021.5 -19.0   0.0   NW   4.0  Gucheng
# 2  1021.5 -19.8   0.0  WNW   4.6  Gucheng
# 3  1022.7 -21.2   0.0    W   2.8  Gucheng
# 4  1023.0 -21.4   0.0  WNW   3.6  Gucheng

# %%
huairou_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Huairou_20130301-20170228.csv")# menginput file huairou yang berbentuk csv
huairou_df.head()# menampilkan 5 data teratas dai file huairou
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    7.0   7.0  3.0  2.0  100.0  91.0  -2.3
# 1   2  2013      3    1     1    4.0   4.0  3.0  NaN  100.0  92.0  -2.7
# 2   3  2013      3    1     2    4.0   4.0  NaN  NaN  100.0  91.0  -3.2
# 3   4  2013      3    1     3    3.0   3.0  3.0  2.0    NaN   NaN  -3.3
# 4   5  2013      3    1     4    3.0   3.0  7.0  NaN  300.0  86.0  -4.1
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1020.3 -20.7   0.0  WNW   3.1  Huairou
# 1  1020.8 -20.5   0.0  NNW   1.5  Huairou
# 2  1020.6 -21.4   0.0   NW   1.8  Huairou
# 3  1021.3 -23.7   0.0  NNW   2.4  Huairou
# 4  1022.1 -22.7   0.0  NNW   2.2  Huairou

# %%
nongzhanguan_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Nongzhanguan_20130301-20170228.csv")# menginput file nongzhanguan yang berbentuk csv
nongzhanguan_df.head()# menampilkan 5 data teratas dai file nongzhanguan
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    5.0  14.0  4.0  12.0  200.0  85.0  -0.5
# 1   2  2013      3    1     1    8.0  12.0  6.0  14.0  200.0  84.0  -0.7
# 2   3  2013      3    1     2    3.0   6.0  5.0  14.0  200.0  83.0  -1.2
# 3   4  2013      3    1     3    5.0   5.0  5.0  14.0  200.0  84.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  6.0  21.0  200.0  77.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM       station
# 0  1024.5 -21.4   0.0  NNW   5.7  Nongzhanguan
# 1  1025.1 -22.1   0.0   NW   3.9  Nongzhanguan
# 2  1025.3 -24.6   0.0  NNW   5.3  Nongzhanguan
# 3  1026.2 -25.5   0.0    N   4.9  Nongzhanguan
# 4  1027.1 -24.5   0.0  NNW   3.2  Nongzhanguan

# %%
shunyi_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Shunyi_20130301-20170228.csv")# menginput file shunyi yang berbentuk csv
shunyi_df.head()# menampilkan 5 data teratas dai file shunyi
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2  NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    3.0   6.0  3.0  8.0  300.0  44.0  -0.9
# 1   2  2013      3    1     1   12.0  12.0  3.0  7.0  300.0  47.0  -1.1
# 2   3  2013      3    1     2   14.0  14.0  NaN  7.0  200.0  22.0  -1.7
# 3   4  2013      3    1     3   12.0  12.0  3.0  5.0    NaN   NaN  -2.1
# 4   5  2013      3    1     4   12.0  12.0  3.0  NaN  200.0  11.0  -2.4
#
#      PRES  DEWP  RAIN  wd  WSPM station
# 0  1025.8 -20.5   0.0  NW   9.3  Shunyi
# 1  1026.1 -21.3   0.0  NW   9.4  Shunyi
# 2  1026.2 -23.0   0.0  NW   8.6  Shunyi
# 3  1027.3 -23.3   0.0  NW   6.6  Shunyi
# 4  1027.7 -22.9   0.0  NW   4.5  Shunyi

# %%
tiantan_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Tiantan_20130301-20170228.csv")# menginput file tiantan yang berbentuk csv
tiantan_df.head()# menampilkan 5 data teratas dai file tiantan
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    6.0   6.0  4.0   8.0  300.0  81.0  -0.5
# 1   2  2013      3    1     1    6.0  29.0  5.0   9.0  300.0  80.0  -0.7
# 2   3  2013      3    1     2    6.0   6.0  4.0  12.0  300.0  75.0  -1.2
# 3   4  2013      3    1     3    6.0   6.0  4.0  12.0  300.0  74.0  -1.4
# 4   5  2013      3    1     4    5.0   5.0  7.0  15.0  400.0  70.0  -1.9
#
#      PRES  DEWP  RAIN   wd  WSPM  station
# 0  1024.5 -21.4   0.0  NNW   5.7  Tiantan
# 1  1025.1 -22.1   0.0   NW   3.9  Tiantan
# 2  1025.3 -24.6   0.0  NNW   5.3  Tiantan
# 3  1026.2 -25.5   0.0    N   4.9  Tiantan
# 4  1027.1 -24.5   0.0  NNW   3.2  Tiantan

# %%
wanliu_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Wanliu_20130301-20170228.csv")# menginput file wanliu yang berbentuk csv
wanliu_df.head()# menampilkan 5 data teratas dai file wanliu
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    8.0   8.0  6.0  28.0  400.0  52.0  -0.7
# 1   2  2013      3    1     1    9.0   9.0  6.0  28.0  400.0  50.0  -1.1
# 2   3  2013      3    1     2    3.0   6.0  NaN  19.0  400.0  55.0  -1.1
# 3   4  2013      3    1     3   11.0  30.0  8.0  14.0    NaN   NaN  -1.4
# 4   5  2013      3    1     4    3.0  13.0  9.0   NaN  300.0  54.0  -2.0
#
#      PRES  DEWP  RAIN   wd  WSPM station
# 0  1023.0 -18.8   0.0  NNW   4.4  Wanliu
# 1  1023.2 -18.2   0.0    N   4.7  Wanliu
# 2  1023.5 -18.2   0.0  NNW   5.6  Wanliu
# 3  1024.5 -19.4   0.0   NW   3.1  Wanliu
# 4  1025.2 -19.5   0.0    N   2.0  Wanliu

# %%
wanshouxigong_df = pd.read_csv("https://raw.githubusercontent.com/marceloreis/HTI/refs/heads/master/PRSA_Data_20130301-20170228/PRSA_Data_Wanshouxigong_20130301-20170228.csv")# menginput file wanshouxigong yang berbentuk csv
wanshouxigong_df.head()# menampilkan 5 data teratas dai file wanshouxigong
# Out:
#    No  year  month  day  hour  PM2.5  PM10  SO2   NO2     CO    O3  TEMP  \
# 0   1  2013      3    1     0    9.0   9.0  6.0  17.0  200.0  62.0   0.3
# 1   2  2013      3    1     1   11.0  11.0  7.0  14.0  200.0  66.0  -0.1
# 2   3  2013      3    1     2    8.0   8.0  NaN  16.0  200.0  59.0  -0.6
# 3   4  2013      3    1     3    8.0   8.0  3.0  16.0    NaN   NaN  -0.7
# 4   5  2013      3    1     4    8.0   8.0  3.0   NaN  300.0  36.0  -0.9
#
#      PRES  DEWP  RAIN   wd  WSPM        station
# 0  1021.9 -19.0   0.0  WNW   2.0  Wanshouxigong
# 1  1022.4 -19.3   0.0  WNW   4.4  Wanshouxigong
# 2  1022.6 -19.7   0.0  WNW   4.7  Wanshouxigong
# 3  1023.5 -20.9   0.0   NW   2.6  Wanshouxigong
# 4  1024.1 -21.7   0.0  WNW   2.5  Wanshouxigong

# %% [markdown]
# **Insight:**
# - Mengetahui dataset yang ditampilkan memiliki atribut seperti no., year, month, day, hour, PM2.5, PM10, SO2, NO2, CO, O3, Temp, Pres, Dewp, Rain, wd, WSPM, dan juga station
# - Atribut yang menjelaskan mengenai polutan yaitu PM2.5, PM10, SO2, NO2, CO, O3
# - Atribut yang menjelaskan mengenai cuaca yaitu Temp, Pres, Dewp, Rain, WSPM
# - Atribut yang menjelaskan mengenai arah angin WD

# %% [markdown]
# ### Assessing Data

# %%
aotizhongxin_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(aotizhongxin_df.isnull().sum()) # Mengeluarkan jumlah missing value pada seluruh atribut
print("Jumlah Duplikasi : ", aotizhongxin_df.duplicated().sum()) #mengecek apakah ada data yang berduplikat
aotizhongxin_df.describe() # Memberikan isight mengenai statistika deskriptif dari seluruh variabel
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34139 non-null  float64
#  6   PM10     34346 non-null  float64
#  7   SO2      34129 non-null  float64
#  8   NO2      34041 non-null  float64
#  9   CO       33288 non-null  float64
#  10  O3       33345 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
changping_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(changping_df.isnull().sum())
print("Jumlah Duplikasi : ", changping_df.duplicated().sum())
changping_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34290 non-null  float64
#  6   PM10     34482 non-null  float64
#  7   SO2      34436 non-null  float64
#  8   NO2      34397 non-null  float64
#  9   CO       33543 non-null  float64
#  10  O3       34460 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
dingling_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(dingling_df.isnull().sum())
print("Jumlah Duplikasi : ", dingling_df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34285 non-null  float64
#  6   PM10     34408 non-null  float64
#  7   SO2      34334 non-null  float64
#  8   NO2      33830 non-null  float64
#  9   CO       33052 non-null  float64
#  10  O3       33850 non-null  float64
#  11  TEMP     35011 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34924 non-null  object
#  16  WSPM     35021 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
dongsi_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(dongsi_df.isnull().sum())
print("Jumlah Duplikasi : ", dongsi_df.duplicated().sum())
dongsi_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34314 non-null  float64
#  6   PM10     34511 non-null  float64
#  7   SO2      34401 non-null  float64
#  8   NO2      33463 non-null  float64
#  9   CO       31867 non-null  float64
#  10  O3       34400 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
guanyuan_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(guanyuan_df.isnull().sum())
print("Jumlah Duplikasi : ", guanyun_df.duplicated().sum())
guanyun_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34448 non-null  float64
#  6   PM10     34635 non-null  float64
#  7   SO2      34590 non-null  float64
#  8   NO2      34405 non-null  float64
#  9   CO       33311 non-null  float64
#  10  O3       33891 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34983 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
gucheng_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(gucheng_df.isnull().sum())
print("Jumlah Duplikasi : ", gucheng_df.duplicated().sum())
gucheng_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34418 non-null  float64
#  6   PM10     34683 non-null  float64
#  7   SO2      34557 non-null  float64
#  8   NO2      34396 non-null  float64
#  9   CO       33663 non-null  float64
#  10  O3       34335 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35014 non-null  float64
#  13  DEWP     35013 non-null  float64
#  14  RAIN     35021 non-null  float64
#  15  wd       34905 non-null  object
#  16  WSPM     35022 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
huairou_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(huairou_df.isnull().sum())
print("Jumlah Duplikasi : ", huairou_df.duplicated().sum())
huairou_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34111 non-null  float64
#  6   PM10     34287 non-null  float64
#  7   SO2      34084 non-null  float64
#  8   NO2      33425 non-null  float64
#  9   CO       33642 non-null  float64
#  10  O3       33913 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35011 non-null  float64
#  13  DEWP     35011 non-null  float64
#  14  RAIN     35009 non-null  float64
#  15  wd       34762 non-null  object
#  16  WSPM     35015 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
nongzhanguan_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(nongzhanguan_df.isnull().sum())
print("Jumlah Duplikasi : ", nongzhanguan_df.duplicated().sum())
nongzhanguan_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34436 non-null  float64
#  6   PM10     34624 non-null  float64
#  7   SO2      34618 non-null  float64
#  8   NO2      34372 non-null  float64
#  9   CO       33858 non-null  float64
#  10  O3       34558 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
shunyi_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(shunyi_df.isnull().sum())
print("Jumlah Duplikasi : ", shunyi_df.duplicated().sum())
shunyi_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34151 non-null  float64
#  6   PM10     34516 non-null  float64
#  7   SO2      33768 non-null  float64
#  8   NO2      33699 non-null  float64
#  9   CO       32886 non-null  float64
#  10  O3       33575 non-null  float64
#  11  TEMP     35013 non-null  float64
#  12  PRES     35013 non-null  float64
#  13  DEWP     35010 non-null  float64
#  14  RAIN     35013 non-null  float64
#  15  wd       34581 non-null  object
#  16  WSPM     35020 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
tiantan_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(tiantan_df.isnull().sum())
print("Jumlah Duplikasi : ", tiantan_df.duplicated().sum())
tiantan_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34387 non-null  float64
#  6   PM10     34467 non-null  float64
#  7   SO2      33946 non-null  float64
#  8   NO2      34320 non-null  float64
#  9   CO       33938 non-null  float64
#  10  O3       34221 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34986 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
wanliu_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(wanliu_df.isnull().sum())
print("Jumlah Duplikasi : ", wanliu_df.duplicated().sum())
wanliu_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34682 non-null  float64
#  6   PM10     34780 non-null  float64
#  7   SO2      34489 non-null  float64
#  8   NO2      33994 non-null  float64
#  9   CO       33252 non-null  float64
#  10  O3       32957 non-null  float64
#  11  TEMP     35044 non-null  float64
#  12  PRES     35044 non-null  float64
#  13  DEWP     35044 non-null  float64
#  14  RAIN     35044 non-null  float64
#  15  wd       34941 non-null  object
#  16  WSPM     35050 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %%
wanshouxigong_df.info() # Melihat karakteristik dari seluruh variabel yang ada
print(wanshouxigong_df.isnull().sum())
print("Jumlah Duplikasi : ", wanshouxigong_df.duplicated().sum())
wanshouxigong_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 18 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   No       35064 non-null  int64
#  1   year     35064 non-null  int64
#  2   month    35064 non-null  int64
#  3   day      35064 non-null  int64
#  4   hour     35064 non-null  int64
#  5   PM2.5    34368 non-null  float64
#  6   PM10     34580 non-null  float64
#  7   SO2      34395 non-null  float64
#  8   NO2      34310 non-null  float64
#  9   CO       33767 non-null  float64
#  10  O3       33986 non-null  float64
#  11  TEMP     35045 non-null  float64
#  12  PRES     35045 non-null  float64
#  13  DEWP     35045 non-null  float64
#  14  RAIN     35045 non-null  float64
#  15  wd       34985 non-null  object
#  16  WSPM     35051 non-null  float64
#  17  station  35064 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 4.8+ MB
# No            0
# ...

# %% [markdown]
# **Insight:**
# - Setiap dataset tidak memiliki data yang berduplikat.
# - Setiap dataset memiliki missing value di variabel PM2.5, PM 10, SO2, NO2, CO, O3, TEMP, PRES, DEWP, RAIN, wd, WSPM.
# - Mengetahui statistika deskriptif setiap dataset.
# - Tahun, bulan, dan hari masih dalam bentuk int. Untuk mempermudah mengetahui tren maka akan ditambahkan variabel yang bertipe data datetime.

# %% [markdown]
# ### Cleaning Data

# %%
aotizhongxin_df["date"] = pd.to_datetime(aotizhongxin_df[["year", "month", "day", "hour"]]) # menambahkan atribut baru berupa penanggalan untuk mempermudah pembentukkan tren
aotizhongxin_df["PM2.5"].interpolate(method= "linear", inplace= True) #Mengisi missing value menggunakan metode interpolasi karena dataset ini termasuk data time series
aotizhongxin_df["PM10"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["SO2"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["NO2"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["CO"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["O3"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["TEMP"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["PRES"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["DEWP"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["RAIN"].interpolate(method= "linear", inplace= True)
aotizhongxin_df["WSPM"].interpolate(method= "linear", inplace= True)
print(aotizhongxin_df.wd.value_counts()) # Melihat jumlah data yang memiliki nilai sama
aotizhongxin_df.fillna(value = "NE", inplace= True) # Mengisi missing value dengan nilai NE (karena paling banyak data tersebut bernilai NE)
aotizhongxin_df.isnull().sum()
# Out:
# wd
# NE     5140
# ENE    3950
# SW     3359
# E      2608
# NNE    2445
# WSW    2212
# SSW    2098
# N      2066
# NW     1860
# ESE    1717
# NNW    1589
# SE     1341
# S      1304
# W      1171
# WNW    1101
# SSE    1022
# Name: count, dtype: int64
# <ipython-input-641-ffadd55689e2>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   aotizhongxin_df["PM2.5"].interpolate(method= "linear", inplace= True) #Mengisi missing value menggunakan metode interpolasi karena dataset ini termasuk data time series
# ...

# %%
changping_df["date"] = pd.to_datetime(changping_df[["year", "month", "day", "hour"]])
changping_df["PM2.5"].interpolate(method= "linear", inplace= True)
changping_df["PM10"].interpolate(method= "linear", inplace= True)
changping_df["SO2"].interpolate(method= "linear", inplace= True)
changping_df["NO2"].interpolate(method= "linear", inplace= True)
changping_df["CO"].interpolate(method= "linear", inplace= True)
changping_df["O3"].interpolate(method= "linear", inplace= True)
changping_df["TEMP"].interpolate(method= "linear", inplace= True)
changping_df["PRES"].interpolate(method= "linear", inplace= True)
changping_df["DEWP"].interpolate(method= "linear", inplace= True)
changping_df["RAIN"].interpolate(method= "linear", inplace= True)
changping_df["WSPM"].interpolate(method= "linear", inplace= True)
print(changping_df.wd.value_counts())
changping_df.fillna(value = "NNW", inplace= True) # Mengisi missing value dengan nilai NNW (karena paling banyak data tersebut bernilai NNW)
changping_df.isnull().sum()
# Out:
# wd
# NNW    4776
# NW     3838
# N      3777
# WNW    2877
# ESE    2786
# E      2427
# NNE    1919
# SSE    1853
# SE     1823
# NE     1721
# S      1700
# W      1412
# ENE    1305
# SSW    1126
# SW      880
# WSW     704
# Name: count, dtype: int64
# <ipython-input-642-231cbe5c217e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   changping_df["PM2.5"].interpolate(method= "linear", inplace= True)
# ...

# %%
dingling_df["date"] = pd.to_datetime(dingling_df[["year", "month", "day", "hour"]])
dingling_df["PM2.5"].interpolate(method= "linear", inplace= True)
dingling_df["PM10"].interpolate(method= "linear", inplace= True)
dingling_df["SO2"].interpolate(method= "linear", inplace= True)
dingling_df["NO2"].fillna(dingling_df["NO2"].mean(), inplace= True) # Menggunakan imputasi karena terdapat missing value yang berada pada data pertama dan kedua
dingling_df["CO"].interpolate(method= "linear", inplace= True)
dingling_df["O3"].interpolate(method= "linear", inplace= True)
dingling_df["TEMP"].interpolate(method= "linear", inplace= True)
dingling_df["PRES"].interpolate(method= "linear", inplace= True)
dingling_df["DEWP"].interpolate(method= "linear", inplace= True)
dingling_df["RAIN"].interpolate(method= "linear", inplace= True)
dingling_df["WSPM"].interpolate(method= "linear", inplace= True)
print(dingling_df.wd.value_counts())
dingling_df.fillna(value = "NNW", inplace= True) # Mengisi missing value dengan nilai NNW (karena paling banyak data tersebut bernilai NNW)
dingling_df.isnull().sum()
# Out:
# <ipython-input-643-a96cd623322b>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dingling_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-643-a96cd623322b>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
dongsi_df["date"] = pd.to_datetime(dongsi_df[["year", "month", "day", "hour"]])
dongsi_df["PM2.5"].interpolate(method= "linear", inplace= True)
dongsi_df["PM10"].interpolate(method= "linear", inplace= True)
dongsi_df["SO2"].interpolate(method= "linear", inplace= True)
dongsi_df["NO2"].interpolate(method= "linear", inplace= True)
dongsi_df["CO"].interpolate(method= "linear", inplace= True)
dongsi_df["O3"].interpolate(method= "linear", inplace= True)
dongsi_df["TEMP"].interpolate(method= "linear", inplace= True)
dongsi_df["PRES"].interpolate(method= "linear", inplace= True)
dongsi_df["DEWP"].interpolate(method= "linear", inplace= True)
dongsi_df["RAIN"].interpolate(method= "linear", inplace= True)
dongsi_df["WSPM"].interpolate(method= "linear", inplace= True)
print(dongsi_df.wd.value_counts())
dongsi_df.fillna(value = "ENE", inplace= True) # Mengisi missing value dengan nilai ENE (karena paling banyak data tersebut bernilai ENE)
dongsi_df.isnull().sum()
# Out:
# <ipython-input-644-1eaf5d877480>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dongsi_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-644-1eaf5d877480>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
guanyuan_df["date"] = pd.to_datetime(guanyuan_df[["year", "month", "day", "hour"]])
guanyuan_df["PM2.5"].interpolate(method= "linear", inplace= True)
guanyuan_df["PM10"].interpolate(method= "linear", inplace= True)
guanyuan_df["SO2"].interpolate(method= "linear", inplace= True)
guanyuan_df["NO2"].interpolate(method= "linear", inplace= True)
guanyuan_df["CO"].interpolate(method= "linear", inplace= True)
guanyuan_df["O3"].interpolate(method= "linear", inplace= True)
guanyuan_df["TEMP"].interpolate(method= "linear", inplace= True)
guanyuan_df["PRES"].interpolate(method= "linear", inplace= True)
guanyuan_df["DEWP"].interpolate(method= "linear", inplace= True)
guanyuan_df["RAIN"].interpolate(method= "linear", inplace= True)
guanyuan_df["WSPM"].interpolate(method= "linear", inplace= True)
print(guanyuan_df.wd.value_counts())
guanyuan_df.fillna(value = "NE", inplace= True) # Mengisi missing value dengan nilai NE (karena paling banyak data tersebut bernilai NE)
guanyuan_df.isnull().sum()
# Out:
# <ipython-input-645-7d168b16c043>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   guanyuan_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-645-7d168b16c043>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
gucheng_df["date"] = pd.to_datetime(gucheng_df[["year", "month", "day", "hour"]])
gucheng_df["PM2.5"].interpolate(method= "linear", inplace= True)
gucheng_df["PM10"].interpolate(method= "linear", inplace= True)
gucheng_df["SO2"].interpolate(method= "linear", inplace= True)
gucheng_df["NO2"].fillna(gucheng_df["NO2"].median(), inplace= True)
gucheng_df["CO"].interpolate(method= "linear", inplace= True)
gucheng_df["O3"].interpolate(method= "linear", inplace= True)
gucheng_df["TEMP"].interpolate(method= "linear", inplace= True)
gucheng_df["PRES"].interpolate(method= "linear", inplace= True)
gucheng_df["DEWP"].interpolate(method= "linear", inplace= True)
gucheng_df["RAIN"].interpolate(method= "linear", inplace= True)
gucheng_df["WSPM"].interpolate(method= "linear", inplace= True)
print(gucheng_df.wd.value_counts())
gucheng_df.fillna(value = "N", inplace= True) # Mengisi missing value dengan nilai N (karena paling banyak data tersebut bernilai N)
gucheng_df.isnull().sum()
# Out:
# <ipython-input-646-91bc267319de>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   gucheng_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-646-91bc267319de>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
huairou_df["date"] = pd.to_datetime(huairou_df[["year", "month", "day", "hour"]])
huairou_df["PM2.5"].interpolate(method= "linear", inplace= True)
huairou_df["PM10"].interpolate(method= "linear", inplace= True)
huairou_df["SO2"].interpolate(method= "linear", inplace= True)
huairou_df["NO2"].interpolate(method= "linear", inplace= True)
huairou_df["CO"].interpolate(method= "linear", inplace= True)
huairou_df["O3"].interpolate(method= "linear", inplace= True)
huairou_df["TEMP"].interpolate(method= "linear", inplace= True)
huairou_df["PRES"].interpolate(method= "linear", inplace= True)
huairou_df["DEWP"].interpolate(method= "linear", inplace= True)
huairou_df["RAIN"].interpolate(method= "linear", inplace= True)
huairou_df["WSPM"].interpolate(method= "linear", inplace= True)
print(huairou_df.wd.value_counts())
huairou_df.fillna(value = "NW", inplace= True) # Mengisi missing value dengan nilai NW (karena paling banyak data tersebut bernilai NW)
huairou_df.isnull().sum()
# Out:
# <ipython-input-647-d57f1bc56266>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   huairou_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-647-d57f1bc56266>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
nongzhanguan_df["date"] = pd.to_datetime(nongzhanguan_df[["year", "month", "day", "hour"]])
nongzhanguan_df["PM2.5"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["PM10"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["SO2"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["NO2"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["CO"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["O3"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["TEMP"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["PRES"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["DEWP"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["RAIN"].interpolate(method= "linear", inplace= True)
nongzhanguan_df["WSPM"].interpolate(method= "linear", inplace= True)
print(nongzhanguan_df.wd.value_counts())
nongzhanguan_df.fillna(value = "ENE", inplace= True) # Mengisi missing value dengan nilai ENE (karena paling banyak data tersebut bernilai ENE)
nongzhanguan_df.isnull().sum()
# Out:
# <ipython-input-648-ec9f99945d03>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   nongzhanguan_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-648-ec9f99945d03>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
shunyi_df["date"] = pd.to_datetime(shunyi_df[["year", "month", "day", "hour"]])
shunyi_df["PM2.5"].interpolate(method= "linear", inplace= True)
shunyi_df["PM10"].interpolate(method= "linear", inplace= True)
shunyi_df["SO2"].interpolate(method= "linear", inplace= True)
shunyi_df["NO2"].interpolate(method= "linear", inplace= True)
shunyi_df["CO"].interpolate(method= "linear", inplace= True)
shunyi_df["O3"].interpolate(method= "linear", inplace= True)
shunyi_df["TEMP"].interpolate(method= "linear", inplace= True)
shunyi_df["PRES"].interpolate(method= "linear", inplace= True)
shunyi_df["DEWP"].interpolate(method= "linear", inplace= True)
shunyi_df["RAIN"].interpolate(method= "linear", inplace= True)
shunyi_df["WSPM"].interpolate(method= "linear", inplace= True)
print(shunyi_df.wd.value_counts())
shunyi_df.fillna(value = "NNE", inplace= True) # Mengisi missing value dengan nilai NNE (karena paling banyak data tersebut bernilai NNE)
shunyi_df.isnull().sum()
# Out:
# <ipython-input-649-ab88796a9ec5>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   shunyi_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-649-ab88796a9ec5>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
tiantan_df["date"] = pd.to_datetime(tiantan_df[["year", "month", "day", "hour"]])
tiantan_df["PM2.5"].interpolate(method= "linear", inplace= True)
tiantan_df["PM10"].interpolate(method= "linear", inplace= True)
tiantan_df["SO2"].interpolate(method= "linear", inplace= True)
tiantan_df["NO2"].interpolate(method= "linear", inplace= True)
tiantan_df["CO"].interpolate(method= "linear", inplace= True)
tiantan_df["O3"].interpolate(method= "linear", inplace= True)
tiantan_df["TEMP"].interpolate(method= "linear", inplace= True)
tiantan_df["PRES"].interpolate(method= "linear", inplace= True)
tiantan_df["DEWP"].interpolate(method= "linear", inplace= True)
tiantan_df["RAIN"].interpolate(method= "linear", inplace= True)
tiantan_df["WSPM"].interpolate(method= "linear", inplace= True)
print(tiantan_df.wd.value_counts())
tiantan_df.fillna(value = "ENE", inplace= True) # Mengisi missing value dengan nilai ENE (karena paling banyak data tersebut bernilai ENE)
tiantan_df.isnull().sum()
# Out:
# <ipython-input-650-5da27b64ebf9>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   tiantan_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-650-5da27b64ebf9>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
wanliu_df["date"] = pd.to_datetime(wanliu_df[["year", "month", "day", "hour"]])
wanliu_df["PM2.5"].interpolate(method= "linear", inplace= True)
wanliu_df["PM10"].interpolate(method= "linear", inplace= True)
wanliu_df["SO2"].interpolate(method= "linear", inplace= True)
wanliu_df["NO2"].interpolate(method= "linear", inplace= True)
wanliu_df["CO"].interpolate(method= "linear", inplace= True)
wanliu_df["O3"].interpolate(method= "linear", inplace= True)
wanliu_df["TEMP"].interpolate(method= "linear", inplace= True)
wanliu_df["PRES"].interpolate(method= "linear", inplace= True)
wanliu_df["DEWP"].interpolate(method= "linear", inplace= True)
wanliu_df["RAIN"].interpolate(method= "linear", inplace= True)
wanliu_df["WSPM"].interpolate(method= "linear", inplace= True)
print(wanliu_df.wd.value_counts())
wanliu_df.fillna(value = "NE", inplace= True) # Mengisi missing value dengan nilai NE (karena paling banyak data tersebut bernilai NE)
wanliu_df.isnull().sum()
# Out:
# <ipython-input-651-a39605d531f5>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanliu_df["PM2.5"].interpolate(method= "linear", inplace= True)
# <ipython-input-651-a39605d531f5>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
wanshouxigong_df["date"] = pd.to_datetime(wanshouxigong_df[["year", "month", "day", "hour"]])
wanshouxigong_df["PM2.5"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["PM10"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["SO2"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["NO2"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["CO"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["O3"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["TEMP"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["PRES"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["DEWP"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["RAIN"].interpolate(method= "linear", inplace= True)
wanshouxigong_df["WSPM"].interpolate(method= "linear", inplace= True)
print(wanshouxigong_df.wd.value_counts())
wanshouxigong_df.fillna(value = "NE", inplace= True) # Mengisi missing value dengan nilai NE (karena paling banyak data tersebut bernilai NE)
wanshouxigong_df.isnull().sum()
# Out:
# wd
# NE     3568
# SW     3428
# ENE    3080
# E      2807
# WNW    2565
# NW     2552
# WSW    2546
# W      2464
# SSW    2457
# ESE    1772
# NNE    1564
# S      1506
# SE     1279
# NNW    1187
# N      1176
# SSE    1034
# Name: count, dtype: int64
# <ipython-input-652-92134d5c9f53>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   wanshouxigong_df["PM2.5"].interpolate(method= "linear", inplace= True)
# ...

# %% [markdown]
# **Insight**
# - Seluruh variabel diisi missing valuenya menggunakan metode interpolasi dikarenakan data berjenis time series. Ada beberapa data yang diisikan menggunakan metode imputasi median dikarenakan saat menggunakan interpolasi ternyata masih ada data yang kosong dikarenakan data tersebut data pertama dan kedua.
# - Variabel wd merupakan variabel yang bertipe data int maka digunakan metode imputasi modulus.

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore ...

# %% [markdown]
# #### Pertanyaan 1

# %%
aotizhongxin_df_PM25_cuaca = aotizhongxin_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]] # Menentukan variabel apa saja yang akan dikorelasikan
aotizhongxin_correlation_matrix = aotizhongxin_df_PM25_cuaca.corr() # Teknik korelasi
aotizhongxin_correlation_long = aotizhongxin_correlation_matrix.reset_index().melt(id_vars="index") # Mengubah indeks matriks korelasi menjadi kolom baru yang eksplisit
aotizhongxin_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"] # Menetapkan kolom baru untuk indeks matriks
PM25_correlation = aotizhongxin_correlation_long[aotizhongxin_correlation_long["Polutan"] == "PM2.5"] # Memfilter data dari dataframe
aotizhongxin_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index() # Mencari nilai korelasi maksimum antara PM2.5 dan variabel lainnya dalam setiap kategori cuaca.
aotizhongxin_max_correlation.set_index("Cuaca", inplace=True) # Mengatur kolom "Cuaca" sebagai indeks.
aotizhongxin_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.123277
# PM2.5     1.000000
# PRES     -0.008796
# RAIN     -0.013780
# TEMP     -0.122505

# %%
changping_df_PM25_cuaca = changping_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
changping_correlation_matrix = changping_df_PM25_cuaca.corr()
changping_correlation_long = changping_correlation_matrix.reset_index().melt(id_vars="index")
changping_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = changping_correlation_long[changping_correlation_long["Polutan"] == "PM2.5"]
changping_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
changping_max_correlation.set_index("Cuaca", inplace=True)
changping_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.112217
# PM2.5     1.000000
# PRES      0.010915
# RAIN     -0.008516
# TEMP     -0.113130

# %%
dingling_df_PM25_cuaca = dingling_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
dingling_correlation_matrix = dingling_df_PM25_cuaca.corr()
dingling_correlation_long = dingling_correlation_matrix.reset_index().melt(id_vars="index")
dingling_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = dingling_correlation_long[dingling_correlation_long["Polutan"] == "PM2.5"]
dingling_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
dingling_max_correlation.set_index("Cuaca", inplace=True)
dingling_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.135109
# PM2.5     1.000000
# PRES     -0.005834
# RAIN     -0.008102
# TEMP     -0.088894

# %%
dongsi_df_PM25_cuaca = dongsi_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
dongsi_correlation_matrix = dongsi_df_PM25_cuaca.corr()
dongsi_correlation_long = dongsi_correlation_matrix.reset_index().melt(id_vars="index")
dongsi_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = dongsi_correlation_long[dongsi_correlation_long["Polutan"] == "PM2.5"]
dongsi_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
dongsi_max_correlation.set_index("Cuaca", inplace=True)
dongsi_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.128231
# PM2.5     1.000000
# PRES     -0.005307
# RAIN     -0.019612
# TEMP     -0.138325

# %%
guanyuan_df_PM25_cuaca = guanyuan_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
guanyuan_correlation_matrix = guanyuan_df_PM25_cuaca.corr()
guanyuan_correlation_long = guanyuan_correlation_matrix.reset_index().melt(id_vars="index")
guanyuan_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = guanyuan_correlation_long[guanyuan_correlation_long["Polutan"] == "PM2.5"]
guanyuan_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
guanyuan_max_correlation.set_index("Cuaca", inplace=True)
guanyuan_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.121088
# PM2.5     1.000000
# PRES     -0.000325
# RAIN     -0.010613
# TEMP     -0.132063

# %%
gucheng_df_PM25_cuaca = gucheng_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
gucheng_correlation_matrix = gucheng_df_PM25_cuaca.corr()
gucheng_correlation_long = gucheng_correlation_matrix.reset_index().melt(id_vars="index")
gucheng_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = gucheng_correlation_long[gucheng_correlation_long["Polutan"] == "PM2.5"]
gucheng_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
gucheng_max_correlation.set_index("Cuaca", inplace=True)
gucheng_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.097060
# PM2.5     1.000000
# PRES      0.022596
# RAIN     -0.020184
# TEMP     -0.145860

# %%
huairou_df_PM25_cuaca = huairou_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
huairou_correlation_matrix = huairou_df_PM25_cuaca.corr()
huairou_correlation_long = huairou_correlation_matrix.reset_index().melt(id_vars="index")
huairou_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = huairou_correlation_long[huairou_correlation_long["Polutan"] == "PM2.5"]
huairou_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
huairou_max_correlation.set_index("Cuaca", inplace=True)
huairou_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.121334
# PM2.5     1.000000
# PRES     -0.005330
# RAIN     -0.012069
# TEMP     -0.077995

# %%
nongzhanguan_df_PM25_cuaca = nongzhanguan_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
nongzhanguan_correlation_matrix = nongzhanguan_df_PM25_cuaca.corr()
nongzhanguan_correlation_long = nongzhanguan_correlation_matrix.reset_index().melt(id_vars="index")
nongzhanguan_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = nongzhanguan_correlation_long[nongzhanguan_correlation_long["Polutan"] == "PM2.5"]
nongzhanguan_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
nongzhanguan_max_correlation.set_index("Cuaca", inplace=True)
nongzhanguan_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.097226
# PM2.5     1.000000
# PRES      0.028121
# RAIN     -0.022705
# TEMP     -0.173362

# %%
shunyi_df_PM25_cuaca = shunyi_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
shunyi_correlation_matrix = shunyi_df_PM25_cuaca.corr()
shunyi_correlation_long = shunyi_correlation_matrix.reset_index().melt(id_vars="index")
shunyi_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = shunyi_correlation_long[shunyi_correlation_long["Polutan"] == "PM2.5"]
shunyi_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
shunyi_max_correlation.set_index("Cuaca", inplace=True)
shunyi_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.118777
# PM2.5     1.000000
# PRES      0.002149
# RAIN     -0.008090
# TEMP     -0.120102

# %%
tiantan_df_PM25_cuaca = tiantan_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
tiantan_correlation_matrix = tiantan_df_PM25_cuaca.corr()
tiantan_correlation_long = tiantan_correlation_matrix.reset_index().melt(id_vars="index")
tiantan_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = tiantan_correlation_long[tiantan_correlation_long["Polutan"] == "PM2.5"]
tiantan_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
tiantan_max_correlation.set_index("Cuaca", inplace=True)
tiantan_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.111542
# PM2.5     1.000000
# PRES      0.009322
# RAIN     -0.015968
# TEMP     -0.152018

# %%
wanliu_df_PM25_cuaca = wanliu_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
wanliu_correlation_matrix = wanliu_df_PM25_cuaca.corr()
wanliu_correlation_long = wanliu_correlation_matrix.reset_index().melt(id_vars="index")
wanliu_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = wanliu_correlation_long[wanliu_correlation_long["Polutan"] == "PM2.5"]
wanliu_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
wanliu_max_correlation.set_index("Cuaca", inplace=True)
wanliu_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.101796
# PM2.5     1.000000
# PRES      0.006564
# RAIN     -0.012708
# TEMP     -0.134334

# %%
wanshouxigong_df_PM25_cuaca = wanshouxigong_df[["PM2.5", "TEMP", "PRES", "DEWP", "RAIN", "WSPM"]]
wanshouxigong_correlation_matrix = wanshouxigong_df_PM25_cuaca.corr()
wanshouxigong_correlation_long = wanshouxigong_correlation_matrix.reset_index().melt(id_vars="index")
wanshouxigong_correlation_long.columns = ["Polutan", "Cuaca", "Correlation"]
PM25_correlation = wanshouxigong_correlation_long[wanshouxigong_correlation_long["Polutan"] == "PM2.5"]
wanshouxigong_max_correlation = PM25_correlation.groupby("Cuaca")["Correlation"].max().reset_index()
wanshouxigong_max_correlation.set_index("Cuaca", inplace=True)
wanshouxigong_max_correlation.head()
# Out:
#        Correlation
# Cuaca
# DEWP      0.074192
# PM2.5     1.000000
# PRES      0.033790
# RAIN     -0.020684
# TEMP     -0.185844

# %%
aotizhongxin_max = pd.DataFrame({"Station": ["Aotizhongxin"], "Cuaca": "DEWP", "Correlation": 0.123277}) # Mengambil data korelasi paling tingii dalam dataframe
changping_max = pd.DataFrame({"Station": ["Changping"], "Cuaca": "DEWP", "Correlation": 0.112217})
dingling_max = pd.DataFrame({"Station": ["Dingling"], "Cuaca": "DEWP", "Correlation": 0.135109})
dongsi_max = pd.DataFrame({"Station": ["Dongsi"], "Cuaca": "DEWP", "Correlation": 0.128231})
guanyuan_max = pd.DataFrame({"Station": ["Guanyuan"], "Cuaca": "DEWP", "Correlation": 0.121088})
gucheng_max = pd.DataFrame({"Station": ["Gucheng"], "Cuaca": "DEWP", "Correlation": 0.097060})
huairou_max = pd.DataFrame({"Station": ["Huairou"], "Cuaca": "DEWP", "Correlation": 0.121334})
nongzhanguan_max = pd.DataFrame({"Station": ["Nongzhanguan"], "Cuaca": "DEWP", "Correlation": 0.097226})
shunyi_max = pd.DataFrame({"Station": ["Shunyi"], "Cuaca": "DEWP", "Correlation": 0.118777})
tiantan_max = pd.DataFrame({"Station": ["Tiantan"], "Cuaca": "DEWP", "Correlation": 0.111542})
wanliu_max = pd.DataFrame({"Station": ["Wanliu"], "Cuaca": "DEWP", "Correlation": 0.101796})
wanshouxigong_max = pd.DataFrame({"Station": ["Wanshouxigong"], "Cuaca": "DEWP", "Correlation": 0.074192})

merged_PM25_cuaca = pd.concat([aotizhongxin_max, changping_max, dingling_max, dongsi_max, guanyuan_max, gucheng_max, huairou_max, nongzhanguan_max, shunyi_max, tiantan_max, wanliu_max, wanshouxigong_max]) # Menggabungkan dataframe
merged_PM25_cuaca = merged_PM25_cuaca.sort_values(by= "Correlation", ascending= False) # Filter merujuk kepada variabel "Correalation" dengan urutan dari besar ke kecil
merged_PM25_cuaca.head(11) # Menampilkan 11 data
# Out:
#         Station Cuaca  Correlation
# 0      Dingling  DEWP     0.135109
# 0        Dongsi  DEWP     0.128231
# 0  Aotizhongxin  DEWP     0.123277
# 0       Huairou  DEWP     0.121334
# 0      Guanyuan  DEWP     0.121088
# 0        Shunyi  DEWP     0.118777
# 0     Changping  DEWP     0.112217
# 0       Tiantan  DEWP     0.111542
# 0        Wanliu  DEWP     0.101796
# 0  Nongzhanguan  DEWP     0.097226
# 0       Gucheng  DEWP     0.097060

# %% [markdown]
# #### Pertanyaan 2

# %%
aotizhongxin_monthly_avg_PM25 = aotizhongxin_df.groupby(aotizhongxin_df["date"].dt.to_period("M"))["PM2.5"].mean() # Menghitung rata-rata perbulannya untuk variabel "PM2.5"
aotizhongxin_monthly_avg_PM25.index = aotizhongxin_monthly_avg_PM25.index.to_timestamp() #mengonversi indeks periode waktu menjadi timestamp
aotizhongxin_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    110.092742
# 2013-04-01     62.751389
# 2013-05-01     85.394489
# 2013-06-01    106.203472
# 2013-07-01     68.911290
# Freq: MS, Name: PM2.5, dtype: float64

# %%
changping_monthly_avg_PM25 = changping_df.groupby(changping_df["date"].dt.to_period("M"))["PM2.5"].mean()
changping_monthly_avg_PM25.index = changping_monthly_avg_PM25.index.to_timestamp()
changping_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    98.916667
# 2013-04-01    59.444444
# 2013-05-01    82.982527
# 2013-06-01    81.061111
# 2013-07-01    61.977151
# Freq: MS, Name: PM2.5, dtype: float64

# %%
dingling_df_monthly_avg_PM25 = dingling_df.groupby(dingling_df["date"].dt.to_period("M"))["PM2.5"].mean()
dingling_df_monthly_avg_PM25.index = dingling_df_monthly_avg_PM25.index.to_timestamp()
dingling_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    95.705645
# 2013-04-01    55.700000
# 2013-05-01    70.633737
# 2013-06-01    86.342325
# 2013-07-01    57.913342
# Freq: MS, Name: PM2.5, dtype: float64

# %%
dongsi_df_monthly_avg_PM25 = dongsi_df.groupby(dongsi_df["date"].dt.to_period("M"))["PM2.5"].mean()
dongsi_df_monthly_avg_PM25.index = dongsi_df_monthly_avg_PM25.index.to_timestamp()
dongsi_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    108.413978
# 2013-04-01     65.280556
# 2013-05-01     91.392473
# 2013-06-01    109.452778
# 2013-07-01     72.967742
# Freq: MS, Name: PM2.5, dtype: float64

# %%
guanyuan_df_monthly_avg_PM25 = guanyuan_df.groupby(guanyuan_df["date"].dt.to_period("M"))["PM2.5"].mean()
guanyuan_df_monthly_avg_PM25.index = guanyuan_df_monthly_avg_PM25.index.to_timestamp()
guanyuan_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    102.719086
# 2013-04-01     59.332639
# 2013-05-01     80.557796
# 2013-06-01    107.015278
# 2013-07-01     65.992608
# Freq: MS, Name: PM2.5, dtype: float64

# %%
gucheng_df_monthly_avg_PM25 = gucheng_df.groupby(gucheng_df["date"].dt.to_period("M"))["PM2.5"].mean()
gucheng_df_monthly_avg_PM25.index = gucheng_df_monthly_avg_PM25.index.to_timestamp()
gucheng_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    108.841398
# 2013-04-01     65.072917
# 2013-05-01     82.610215
# 2013-06-01    103.265278
# 2013-07-01     61.690860
# Freq: MS, Name: PM2.5, dtype: float64

# %%
huairou_df_monthly_avg_PM25 = huairou_df.groupby(huairou_df["date"].dt.to_period("M"))["PM2.5"].mean()
huairou_df_monthly_avg_PM25.index = huairou_df_monthly_avg_PM25.index.to_timestamp()
huairou_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    95.836022
# 2013-04-01    57.355556
# 2013-05-01    76.613575
# 2013-06-01    74.812500
# 2013-07-01    62.099462
# Freq: MS, Name: PM2.5, dtype: float64

# %%
nongzhanguan_df_monthly_avg_PM25 = nongzhanguan_df.groupby(nongzhanguan_df["date"].dt.to_period("M"))["PM2.5"].mean()
nongzhanguan_df_monthly_avg_PM25.index = nongzhanguan_df_monthly_avg_PM25.index.to_timestamp()
nongzhanguan_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    106.770161
# 2013-04-01     57.350000
# 2013-05-01     77.247312
# 2013-06-01    108.320139
# 2013-07-01     75.435484
# Freq: MS, Name: PM2.5, dtype: float64

# %%
shunyi_df_monthly_avg_PM25 = shunyi_df.groupby(shunyi_df["date"].dt.to_period("M"))["PM2.5"].mean()
shunyi_df_monthly_avg_PM25.index = shunyi_df_monthly_avg_PM25.index.to_timestamp()
shunyi_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    104.636425
# 2013-04-01     57.781250
# 2013-05-01     79.924059
# 2013-06-01    105.725000
# 2013-07-01     61.924731
# Freq: MS, Name: PM2.5, dtype: float64

# %%
tiantan_df_monthly_avg_PM25 = tiantan_df.groupby(tiantan_df["date"].dt.to_period("M"))["PM2.5"].mean()
tiantan_df_monthly_avg_PM25.index = tiantan_df_monthly_avg_PM25.index.to_timestamp()
tiantan_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    105.959005
# 2013-04-01     60.973611
# 2013-05-01     80.413306
# 2013-06-01    110.459028
# 2013-07-01     69.298387
# Freq: MS, Name: PM2.5, dtype: float64

# %%
wanliu_df_monthly_avg_PM25 = wanliu_df.groupby(wanliu_df["date"].dt.to_period("M"))["PM2.5"].mean()
wanliu_df_monthly_avg_PM25.index = wanliu_df_monthly_avg_PM25.index.to_timestamp()
wanliu_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    110.272849
# 2013-04-01     66.541667
# 2013-05-01     92.978495
# 2013-06-01    119.980556
# 2013-07-01     75.714382
# Freq: MS, Name: PM2.5, dtype: float64

# %%
wanshouxigong_df_monthly_avg_PM25 = wanshouxigong_df.groupby(wanshouxigong_df["date"].dt.to_period("M"))["PM2.5"].mean()
wanshouxigong_df_monthly_avg_PM25.index = wanshouxigong_df_monthly_avg_PM25.index.to_timestamp()
wanshouxigong_df_monthly_avg_PM25.head()
# Out:
# date
# 2013-03-01    106.698925
# 2013-04-01     78.903472
# 2013-05-01     81.770161
# 2013-06-01    105.869444
# 2013-07-01     68.150538
# Freq: MS, Name: PM2.5, dtype: float64

# %% [markdown]
# **Insight:**
# - Didapatkan cuaca yang paling mempengaruhi PM2.5 pada setiap station adalah DEWP yang berkorelasi paling tinggi sebesar 0.135109 pada Dingling station.
# - Didapatkan pula nilai mean perbulannya untuk setiap station pada konsentrasi PM2.5 yang dilihat secara sekilas bertren musiman.

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
aotizhongxin_correlation_matrix = aotizhongxin_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8)) #membuat canvas baru dengan ukuran 10X8
sns.heatmap(aotizhongxin_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5) # Membuat Heatmap korelasi
plt.title("Heatmap Correlation at Aotizhongxin Station", loc= "center", fontsize= 20) # Memberikan judul untuk Heatmap
plt.show() # Menampilkan Heatmap

# %%
changping_correlation_matrix = changping_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(changping_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Changping Station", loc= "center", fontsize= 20)
plt.show()

# %%
dingling_correlation_matrix = dingling_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(dingling_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Dingling Station", loc= "center", fontsize= 20)
plt.show()

# %%
dongsi_correlation_matrix = dongsi_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(dongsi_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Dongsi Station", loc= "center", fontsize= 20)
plt.show()

# %%
guanyuan_correlation_matrix = guanyuan_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(guanyuan_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Guanyuan Station", loc= "center", fontsize= 20)
plt.show()

# %%
gucheng_correlation_matrix = gucheng_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(gucheng_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Gucheng Station", loc= "center", fontsize= 20)
plt.show()

# %%
huairou_correlation_matrix = huairou_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(huairou_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Huairou Station", loc= "center", fontsize= 20)
plt.show()

# %%
nongzhanguan_correlation_matrix = nongzhanguan_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(nongzhanguan_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Nongzhanguan Station", loc= "center", fontsize= 20)
plt.show()

# %%
shunyi_correlation_matrix = shunyi_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(shunyi_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Shunyi Station", loc= "center", fontsize= 20)
plt.show()

# %%
tiantan_correlation_matrix = tiantan_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(tiantan_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Tiantan Station", loc= "center", fontsize= 20)
plt.show()

# %%
wanliu_correlation_matrix = wanliu_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(wanliu_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Wanliu Station", loc= "center", fontsize= 20)
plt.show()

# %%
wanshouxigong_correlation_matrix = wanshouxigong_df_PM25_cuaca.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(wanshouxigong_correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Heatmap Correlation at Wanshouxigong Station", loc= "center", fontsize= 20)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(data=merged_PM25_cuaca, x="Station", y="Correlation") # Membuat barchart dengan x nilai dari "station" dan y nya nilai dari "Correlation"
plt.xlabel("Station", fontsize=15)
plt.xticks(fontsize=10, rotation=15)
plt.ylabel("Correlation", fontsize=15)
plt.title("DEWP Correlation with PM2.5 for each Station", fontsize= 20)
plt.show()

# %% [markdown]
# ### Pertanyaan 2:

# %%
plt.figure(figsize=(12, 6))
plt.plot(aotizhongxin_monthly_avg_PM25.index, # Sebagai x
         aotizhongxin_monthly_avg_PM25.values, # Sebagai y
         marker="o", # titiknya di lambangkan o
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Aotizhongxin Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(changping_monthly_avg_PM25.index,
         changping_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Changping Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(dingling_df_monthly_avg_PM25.index,
         dingling_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Dingling Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(dongsi_df_monthly_avg_PM25.index,
         dongsi_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Dongsi Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(guanyuan_df_monthly_avg_PM25.index,
         guanyuan_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Guanyuan Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(gucheng_df_monthly_avg_PM25.index,
         gucheng_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Gucheng Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(huairou_df_monthly_avg_PM25.index,
         huairou_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Huairou Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(nongzhanguan_df_monthly_avg_PM25.index,
         nongzhanguan_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Nongzhanguan Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(shunyi_df_monthly_avg_PM25.index,
         shunyi_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Shunyi Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(tiantan_df_monthly_avg_PM25.index,
         tiantan_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Tiantan Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(wanliu_df_monthly_avg_PM25.index,
         wanliu_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Wanliu Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(wanshouxigong_df_monthly_avg_PM25.index,
         wanshouxigong_df_monthly_avg_PM25.values,
         marker="o",
         linestyle="-",
         color="b")
plt.xlabel("Date (Month)", fontsize=15)
plt.ylabel("Average PM2.5", fontsize=15)
plt.title("Monthly Average PM2.5 at Wanshouxigong Station", fontsize=20)
plt.xticks(rotation=15)
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# **Insight:**
# - Terlihat pada Heatmap yang terbentuk untuk setiap station yaitu PM2.5 berkorelasi dengan DEWP menrupakan korelasi yang paling tinggi dibandingkan dengan faktor cuaca lainnya dengan ditampilkan angka yang lebih tinggi dari yang lainnya dan warna yang lebih warm dari yang lainnya.
# - Terlihat juga perbandingan nilai korelasi DEWP dengan PM2.5. Didapat Dingling Station mendapatkaan nilai korelasi yang paling tinggi dibandingkan dengan station lainnya dengan nilai korelasi yaitu 0.135109.
# - Terlihat bahwasannya pada setiap Line chart untuk setiap stationnya bergerak naik dan turun, maka tren dari PM2.5 untuk setiap tahunnya berupa tren musiman.

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Untuk setiap station, cuaca yang berpengaruh pada PM2.5 yaitu DEWP dengan nilai korelasi bernilai positif. Akan tetapi nilai korelasi yang terbentuk rentang 0-0,14 yang bisa diartikan kalau DEWP berpengaruh sedikit terhadap PM2.5. Maka diperlukannya data tambahan untuk mencari tahu faktor yang paling berpengaruh pada PM2.5.
# - Untuk setiap station, pola atau tren PM2.5 perbulannya yang terbentuk berupa tren musiman dikarenakan seiring berjalannya waktu titik tersebut selalu naik dan turun.
